# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset = pd.read_csv('3_7431_Churn_Modelling.csv', index_col = 'RowNumber')
dataset.head()
# Out:
#            CustomerId   Surname  CreditScore Geography  Gender  Age  Tenure  \
# RowNumber
# 1            15634602  Hargrave          619    France  Female   42       2
# 2            15647311      Hill          608     Spain  Female   41       1
# 3            15619304      Onio          502    France  Female   42       8
# 4            15701354      Boni          699    France  Female   39       1
# 5            15737888  Mitchell          850     Spain  Female   43       2
#
#              Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# RowNumber
# 1               0.00              1          1               1
# 2           83807.86              1          0               1
# 3          159660.80              3          1               0
# 4               0.00              2          0               0
# 5          125510.82              1          1               1
#
#            EstimatedSalary  Exited
# RowNumber
# 1                101348.88       1
# 2                112542.58       0
# 3                113931.57       1
# 4                 93826.63       0
# 5                 79084.10       0

# %%
#Customer ID and Surname would not be relevant as features
X_columns = dataset.columns.tolist()[2:12]
Y_columns = dataset.columns.tolist()[-1:]
print(X_columns)
print(Y_columns)
# Out:
# ['CreditScore', 'Geography', 'Gender', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard', 'IsActiveMember', 'EstimatedSalary']
# ['Exited']

# %%
X = dataset[X_columns].values 
Y = dataset[Y_columns].values

# %%
#We need to encode categorical variables such as geography and gender
from sklearn.preprocessing import LabelEncoder
X_column_transformer = LabelEncoder()
X[:, 1] = X_column_transformer.fit_transform(X[:, 1])

# %%
#Lets Encode gender now
X[:, 2] = X_column_transformer.fit_transform(X[:, 2])

# %%
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline

pipeline = Pipeline(
    [
        ('Categorizer', ColumnTransformer(
            [
                ("Gender Label Encoder", OneHotEncoder(categories = 'auto', drop = 'first'), [2]),
                ("Geography Label Encoder", OneHotEncoder(categories = 'auto', drop = 'first'), [1])
            ], 
            remainder = 'passthrough', n_jobs = 1)),
        ('Normalizer', StandardScaler())
    ]
)

# %%
#Standardize the features
X = pipeline.fit_transform(X)

# %%
#Spilt the data
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size = 0.2, random_state = 0)

# %%
#Let us create the Neural Network
from keras.models import Sequential
from keras.layers import Dense, Dropout

# %%
#Initialize ANN
classifier = Sequential()

# %%
#Add input layer and hidden layer
classifier.add(Dense(6, activation = 'relu', input_shape = (X_train.shape[1], )))
classifier.add(Dropout(rate = 0.1))
# Out:
# /home/csl4/.local/lib/python3.10/site-packages/keras/src/layers/core/dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2025-09-08 13:02:01.481880: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)

# %%
#Add second layer
classifier.add(Dense(6, activation = 'relu'))
classifier.add(Dropout(rate = 0.1))

# %%
#Add output layer
classifier.add(Dense(1, activation = 'sigmoid'))

# %%
#Let us take a look at our network
classifier.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 6)              │            72 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 6)              │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 6)              │            42 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 6)              │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │             7 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 121 (484.00 B)
#  Trainable params: 121 (484.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
#Optimize the weights
classifier.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# %%
#Fitting the Neural Network
history = classifier.fit(X_train, y_train, batch_size = 32, epochs = 200, validation_split = 0.1, verbose = 2)
# Out:
# Epoch 1/200
# 225/225 - 3s - 11ms/step - accuracy: 0.7281 - loss: 0.5572 - val_accuracy: 0.7950 - val_loss: 0.4877
# Epoch 2/200
# 225/225 - 0s - 2ms/step - accuracy: 0.7954 - loss: 0.4892 - val_accuracy: 0.7950 - val_loss: 0.4578
# Epoch 3/200
# 225/225 - 0s - 2ms/step - accuracy: 0.7957 - loss: 0.4709 - val_accuracy: 0.7950 - val_loss: 0.4415
# Epoch 4/200
# 225/225 - 0s - 2ms/step - accuracy: 0.7958 - loss: 0.4578 - val_accuracy: 0.7950 - val_loss: 0.4304
# Epoch 5/200
# 225/225 - 0s - 2ms/step - accuracy: 0.7960 - loss: 0.4546 - val_accuracy: 0.7950 - val_loss: 0.4244
# Epoch 6/200
# 225/225 - 0s - 2ms/step - accuracy: 0.7962 - loss: 0.4449 - val_accuracy: 0.7950 - val_loss: 0.4211
# Epoch 7/200
# 225/225 - 0s - 2ms/step - accuracy: 0.7967 - loss: 0.4452 - val_accuracy: 0.7950 - val_loss: 0.4182
# Epoch 8/200
# 225/225 - 0s - 2ms/step - accuracy: 0.7961 - loss: 0.4431 - val_accuracy: 0.7950 - val_loss: 0.4165
# Epoch 9/200
# 225/225 - 0s - 2ms/step - accuracy: 0.7974 - loss: 0.4404 - val_accuracy: 0.7950 - val_loss: 0.4142
# Epoch 10/200
# 225/225 - 0s - 2ms/step - accuracy: 0.7986 - loss: 0.4397 - val_accuracy: 0.7975 - val_loss: 0.4115
# Epoch 11/200
# 225/225 - 0s - 2ms/step - accuracy: 0.8021 - loss: 0.4354 - val_accuracy: 0.8050 - val_loss: 0.4095
# Epoch 12/200
# 225/225 - 0s - 2ms/step - accuracy: 0.8046 - loss: 0.4344 - val_accuracy: 0.8100 - val_loss: 0.4063
# Epoch 13/200
# 225/225 - 0s - 2ms/step - accuracy: 0.8035 - loss: 0.4325 - val_accuracy: 0.8087 - val_loss: 0.4041
# Epoch 14/200
# 225/225 - 0s - 2ms/step - accuracy: 0.8053 - loss: 0.4271 - val_accuracy: 0.8100 - val_loss: 0.4013
# Epoch 15/200
# 225/225 - 0s - 2ms/step - accuracy: 0.8072 - loss: 0.4273 - val_accuracy: 0.8100 - val_loss: 0.3975
# Epoch 16/200
# 225/225 - 0s - 2ms/step - accuracy: 0.8092 - loss: 0.4209 - val_accuracy: 0.8112 - val_loss: 0.3937
# Epoch 17/200
# 225/225 - 0s - 2ms/step - accuracy: 0.8111 - loss: 0.4131 - val_accuracy: 0.8100 - val_loss: 0.3861
# Epoch 18/200
# 225/225 - 0s - 2ms/step - accuracy: 0.8140 - loss: 0.4089 - val_accuracy: 0.8087 - val_loss: 0.3801
# Epoch 19/200
# 225/225 - 0s - 2ms/step - accuracy: 0.8160 - loss: 0.4028 - val_accuracy: 0.8100 - val_loss: 0.3753
# Epoch 20/200
# 225/225 - 0s - 2ms/step - accuracy: 0.8158 - loss: 0.4001 - val_accuracy: 0.8125 - val_loss: 0.3717
# Epoch 21/200
# 225/225 - 0s - 2ms/step - accuracy: 0.8160 - loss: 0.3949 - val_accuracy: 0.8125 - val_loss: 0.3673
# Epoch 22/200
# 225/225 - 0s - 2ms/step - accuracy: 0.8151 - loss: 0.4000 - val_accuracy: 0.8125 - val_loss: 0.3657
# Epoch 23/200
# 225/225 - 0s - 2ms/step - accuracy: 0.8167 - loss: 0.3962 - val_accuracy: 0.8125 - val_loss: 0.3649
# Epoch 24/200
# 225/225 - 0s - 2ms/step - accuracy: 0.8172 - loss: 0.3883 - val_accuracy: 0.8125 - val_loss: 0.3627
# Epoch 25/200
# 225/225 - 0s - 2ms/step - accuracy: 0.8171 - loss: 0.3964 - val_accuracy: 0.8125 - val_loss: 0.3616
# Epoch 26/200
# 225/225 - 0s - 2ms/step - accuracy: 0.8168 - loss: 0.3909 - val_accuracy: 0.8125 - val_loss: 0.3614
# Epoch 27/200
# 225/225 - 0s - 2ms/step - accuracy: 0.8165 - loss: 0.3939 - val_accuracy: 0.8125 - val_loss: 0.3598
# Epoch 28/200
# 225/225 - 0s - 2ms/step - accuracy: 0.8161 - loss: 0.3932 - val_accuracy: 0.8125 - val_loss: 0.3596
# Epoch 29/200
# 225/225 - 0s - 2ms/step - accuracy: 0.
200
# 225/225 - 0s - 2ms/step - accuracy: 0.8537 - loss: 0.3789 - val_accuracy: 0.8637 - val_loss: 0.3454
# Epoch 180/200
# 225/225 - 0s - 2ms/step - accuracy: 0.8531 - loss: 0.3856 - val_accuracy: 0.8662 - val_loss: 0.3458
# Epoch 181/200
# 225/225 - 0s - 2ms/step - accuracy: 0.8497 - loss: 0.3848 - val_accuracy: 0.8650 - val_loss: 0.3467
# Epoch 182/200
# 225/225 - 0s - 2ms/step - accuracy: 0.8522 - loss: 0.3839 - val_accuracy: 0.8637 - val_loss: 0.3464
# Epoch 183/200
# 225/225 - 0s - 2ms/step - accuracy: 0.8521 - loss: 0.3850 - val_accuracy: 0.8662 - val_loss: 0.3463
# Epoch 184/200
# 225/225 - 0s - 2ms/step - accuracy: 0.8531 - loss: 0.3813 - val_accuracy: 0.8637 - val_loss: 0.3471
# Epoch 185/200
# 225/225 - 1s - 3ms/step - accuracy: 0.8506 - loss: 0.3837 - val_accuracy: 0.8637 - val_loss: 0.3462
# Epoch 186/200
# 225/225 - 0s - 2ms/step - accuracy: 0.8543 - loss: 0.3811 - val_accuracy: 0.8675 - val_loss: 0.3468
# Epoch 187/200
# 225/225 - 0s - 2ms/step - accuracy: 0.8508 - loss: 0.3794 - val_accuracy: 0.8637 - val_loss: 0.3461
# Epoch 188/200
# 225/225 - 0s - 2ms/step - accuracy: 0.8518 - loss: 0.3872 - val_accuracy: 0.8662 - val_loss: 0.3464
# Epoch 189/200
# 225/225 - 0s - 2ms/step - accuracy: 0.8537 - loss: 0.3814 - val_accuracy: 0.8637 - val_loss: 0.3464
# Epoch 190/200
# 225/225 - 0s - 2ms/step - accuracy: 0.8557 - loss: 0.3781 - val_accuracy: 0.8650 - val_loss: 0.3459
# Epoch 191/200
# 225/225 - 1s - 3ms/step - accuracy: 0.8500 - loss: 0.3829 - val_accuracy: 0.8637 - val_loss: 0.3462
# Epoch 192/200
# 225/225 - 1s - 4ms/step - accuracy: 0.8521 - loss: 0.3788 - val_accuracy: 0.8650 - val_loss: 0.3457
# Epoch 193/200
# 225/225 - 1s - 4ms/step - accuracy: 0.8529 - loss: 0.3760 - val_accuracy: 0.8637 - val_loss: 0.3458
# Epoch 194/200
# 225/225 - 0s - 2ms/step - accuracy: 0.8529 - loss: 0.3796 - val_accuracy: 0.8637 - val_loss: 0.3459
# Epoch 195/200
# 225/225 - 0s - 2ms/step - accuracy: 0.8524 - loss: 0.3856 - val_accuracy: 0.8662 - val_loss: 0.3462
# Epoch 196/200
# 225/225 - 1s - 4ms/step - accuracy: 0.8528 - loss: 0.3837 - val_accuracy: 0.8650 - val_loss: 0.3458
# Epoch 197/200
# 225/225 - 1s - 5ms/step - accuracy: 0.8514 - loss: 0.3855 - val_accuracy: 0.8612 - val_loss: 0.3461
# Epoch 198/200
# 225/225 - 1s - 2ms/step - accuracy: 0.8528 - loss: 0.3834 - val_accuracy: 0.8612 - val_loss: 0.3462
# Epoch 199/200
# 225/225 - 0s - 2ms/step - accuracy: 0.8539 - loss: 0.3821 - val_accuracy: 0.8600 - val_loss: 0.3464
# Epoch 200/200
# 225/225 - 0s - 2ms/step - accuracy: 0.8528 - loss: 0.3840 - val_accuracy: 0.8625 - val_loss: 0.3466

# %%
y_pred = classifier.predict(X_test)
print(y_pred[:5])
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# [[0.3127068 ]
#  [0.3794512 ]
#  [0.19456652]
#  [0.08286418]
#  [0.08852829]]

# %%
#Let us use confusion matrix with cutoff value as 0.5
y_pred = (y_pred > 0.5).astype(int)
print(y_pred[:5])
# Out:
# [[0]
#  [0]
#  [0]
#  [0]
#  [0]]

# %%
#Making the Matrix
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)
print(cm)
# Out:
# [[1543   52]
#  [ 213  192]]

# %%
#Accuracy of our NN
print(((cm[0][0] + cm[1][1])* 100) / len(y_test), '% of data was classified correctly')
# Out:
# 86.75 % of data was classified correctly
